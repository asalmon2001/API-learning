# %% [markdown]
# # Welcome
#
# This is my second script where I will further explore the astronomy api in weatherapi.com

# %%
import requests
import json
import pandas as pd
import numpy as np
import datetime as dt
from datetime import datetime

# %%
api_key = "57062ddc0e9d492691c162324231409"
params = { 'key':api_key , 'q':'Calgary'}

# %% [markdown]
# Lets first analyze what is given in the call

# %%
sample_response = requests.get("http://api.weatherapi.com/v1/astronomy.json", params=params)
print(sample_response.status_code)
# Out:
# 200

# %%
str_sample_response = json.dumps(obj=sample_response.json(), indent=2)
print(str_sample_response)
# Out:
# {
#   "location": {
#     "name": "Calgary",
#     "region": "Alberta",
#     "country": "Canada",
#     "lat": 51.08,
#     "lon": -114.08,
#     "tz_id": "America/Edmonton",
#     "localtime_epoch": 1694732317,
#     "localtime": "2023-09-14 16:58"
#   },
#   "astronomy": {
#     "astro": {
#       "sunrise": "07:10 AM",
#       "sunset": "07:53 PM",
#       "moonrise": "06:32 AM",
#       "moonset": "08:04 PM",
#       "moon_phase": "New Moon",
#       "moon_illumination": "1",
#       "is_moon_up": 1,
#       "is_sun_up": 1
#     }
#   }
# }

# %% [markdown]
# # Idea 1: Plotting Rises and Sets
#
# - Plot sunrise/sunset over a year
# - Plot moonrise/moonset over a year
#
# Lets try this process:
# 1. Collect the data and save it to a .csv on local host
# 2. Load the .csv and plot
#
# This will allow me to only have to make the API calls once. Lets begin :)

# %% [markdown]
# ## Part 1: Data collection

# %%
# First off, we actually want historical data

params = { 'key':api_key , 'q':'Calgary', 'dt':'2023-09-13' }
sample_response = requests.get("http://api.weatherapi.com/v1/history.json", params=params)
print(json.dumps(sample_response.json(), indent=2))
# Out:
# {
#   "location": {
#     "name": "Calgary",
#     "region": "Alberta",
#     "country": "Canada",
#     "lat": 51.08,
#     "lon": -114.08,
#     "tz_id": "America/Edmonton",
#     "localtime_epoch": 1694734656,
#     "localtime": "2023-09-14 17:37"
#   },
#   "forecast": {
#     "forecastday": [
#       {
#         "date": "2023-09-13",
#         "date_epoch": 1694563200,
#         "day": {
#           "maxtemp_c": 22.5,
#           "maxtemp_f": 72.5,
#           "mintemp_c": 10.5,
#           "mintemp_f": 50.9,
#           "avgtemp_c": 15.4,
#           "avgtemp_f": 59.8,
#           "maxwind_mph": 5.4,
#           "maxwind_kph": 8.6,
#           "totalprecip_mm": 0.0,
#           "totalprecip_in": 0.0,
#           "avgvis_km": 9.9,
#           "avgvis_miles": 6.0,
#           "avghumidity": 63.0,
#           "condition": {
#             "text": "Thundery outbreaks possible",
#             "icon": "//cdn.weatherapi.com/weather/64x64/day/200.png",
#             "code": 1087
#           },
#           "uv": 5.0
#         },
#         "astro": {
#           "sunrise": "07:08 AM",
#           "sunset": "07:55 PM",
#           "moonrise": "05:21 AM",
#           "moonset": "07:53 PM",
#           "moon_phase": "Waning Crescent",
#           "moon_illumination": "4"
#         },
#         "hour": [
#           {
#             "time_epoch": 1694584800,
#             "time": "2023-09-13 00:00",
#             "temp_c": 16.8,
#             "temp_f": 62.2,
#             "is_day": 0,
#             "condition": {
#               "text": "Overcast",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/122.png",
#               "code": 1009
#             },
#             "wind_mph": 4.5,
#             "wind_kph": 7.2,
#             "wind_degree": 291,
#             "wind_dir": "WNW",
#             "pressure_mb": 1010.0,
#             "pressure_in": 29.83,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 53,
#             "cloud": 100,
#             "feelslike_c": 16.8,
#             "feelslike_f": 62.2,
#             "windchill_c": 16.8,
#             "windchill_f": 62.2,
#             "heatindex_c": 16.8,
#             "heatindex_f": 62.2,
#             "dewpoint_c": 7.1,
#             "dewpoint_f": 44.8,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 8.3,
#             "gust_kph": 13.3,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694588400,
#             "time": "2023-09-13 01:00",
#             "temp_c": 12.2,
#             "temp_f": 54.0,
#             "is_day": 0,
#             "condition": {
#               "text": "Partly cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/116.png",
#               "code": 1003
#             },
#             "wind_mph": 3.6,
#             "wind_kph": 5.8,
#             "wind_degree": 281,
#             "wind_dir": "WNW",
#             "pressure_mb": 1009.0,
#             "pressure_in": 29.79,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 86,
#             "cloud": 56,
#             "feelslike_c": 12.1,
#             "feelslike_f": 53.8,
#             "windchill_c": 12.1,
#             "windchill_f": 53.8,
#             "heatindex_c": 12.2,
#             "heatindex_f": 54.0,
#             "dewpoint_c": 10.0,
#             "dewpoint_f": 50.0,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 6.5,
#             "gust_kph": 10.4,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694592000,
#             "time": "2023-09-13 02:00",
#             "temp_c": 12.3,
#             "temp_f": 54.1,
#             "is_day": 0,
#             "condition": {
#               "text": "Partly cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/116.png",
#               "code": 1003
#             },
#             "wind_mph": 3.1,
#             "wind_kph": 5.0,
#             "wind_degree": 275,
#             "wind_dir": "W",
#             "pressure_mb": 1009.0,
#             "pressure_in": 29.8,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 85,
#             "cloud": 55,
#             "feelslike_c": 12.3,
#             "feelslike_f": 54.1,
#             "windchill_c": 12.3,
#             "windchill_f": 54.1,
#             "heatindex_c": 12.3,
#             "heatindex_f": 54.1,
#             "dewpoint_c": 9.9,
#             "dewpoint_f": 49.8,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 5.8,
#             "gust_kph": 9.4,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694595600,
#             "time": "2023-09-13 03:00",
#             "temp_c": 12.7,
#             "temp_f": 54.9,
#             "is_day": 0,
#             "condition": {
#               "text": "Partly cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/116.png",
#               "code": 1003
#             },
#             "wind_mph": 3.1,
#             "wind_kph": 5.0,
#             "wind_degree": 278,
#             "wind_dir": "W",
#             "pressure_mb": 1011.0,
#             "pressure_in": 29.87,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 64,
#             "cloud": 36,
#             "feelslike_c": 11.7,
#             "feelslike_f": 53.1,
#             "windchill_c": 11.7,
#             "windchill_f": 53.1,
#             "heatindex_c": 12.7,
#             "heatindex_f": 54.9,
#             "dewpoint_c": 6.0,
#             "dewpoint_f": 42.8,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 5.8,
#             "gust_kph": 9.4,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694599200,
#             "time": "2023-09-13 04:00",
#             "temp_c": 12.2,
#             "temp_f": 54.0,
#             "is_day": 0,
#             "condition": {
#               "text": "Partly cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/116.png",
#               "code": 1003
#             },
#             "wind_mph": 2.5,
#             "wind_kph": 4.0,
#             "wind_degree": 252,
#             "wind_dir": "WSW",
#             "pressure_mb": 1009.0,
#             "pressure_in": 29.79,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 85,
#             "cloud": 48,
#             "feelslike_c": 12.6,
#             "feelslike_f": 54.7,
#             "windchill_c": 12.6,
#             "windchill_f": 54.7,
#             "heatindex_c": 12.2,
#             "heatindex_f": 54.0,
#             "dewpoint_c": 9.8,
#             "dewpoint_f": 49.6,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 4.5,
#             "gust_kph": 7.2,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694602800,
#             "time": "2023-09-13 05:00",
#             "temp_c": 11.4,
#             "temp_f": 52.5,
#             "is_day": 0,
#             "condition": {
#               "text": "Partly cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/116.png",
#               "code": 1003
#             },
#             "wind_mph": 3.1,
#             "wind_kph": 5.0,
#             "wind_degree": 287,
#             "wind_dir": "WNW",
#             "pressure_mb": 1009.0,
#             "pressure_in": 29.81,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 88,
#             "cloud": 53,
#             "feelslike_c": 11.3,
#             "feelslike_f": 52.3,
#             "windchill_c": 11.3,
#             "windchill_f": 52.3,
#             "heatindex_c": 11.4,
#             "heatindex_f": 52.5,
#             "dewpoint_c": 9.5,
#             "dewpoint_f": 49.1,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 6.3,
#             "gust_kph": 10.1,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694606400,
#             "time": "2023-09-13 06:00",
#             "temp_c": 11.2,
#             "temp_f": 52.2,
#             "is_day": 0,
#             "condition": {
#               "text": "Clear",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/113.png",
#               "code": 1000
#             },
#             "wind_mph": 3.1,
#             "wind_kph": 5.0,
#             "wind_degree": 311,
#             "wind_dir": "NW",
#             "pressure_mb": 1013.0,
#             "pressure_in": 29.9,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 71,
#             "cloud": 23,
#             "feelslike_c": 9.7,
#             "feelslike_f": 49.5,
#             "windchill_c": 9.7,
#             "windchill_f": 49.5,
#             "heatindex_c": 11.2,
#             "heatindex_f": 52.2,
#             "dewpoint_c": 6.1,
#             "dewpoint_f": 43.0,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 6.5,
#             "gust_kph": 10.4,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694610000,
#             "time": "2023-09-13 07:00",
#             "temp_c": 10.5,
#             "temp_f": 50.9,
#             "is_day": 0,
#             "condition": {
#               "text": "Partly cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/116.png",
#               "code": 1003
#             },
#             "wind_mph": 3.4,
#             "wind_kph": 5.4,
#             "wind_degree": 284,
#             "wind_dir": "WNW",
#             "pressure_mb": 1011.0,
#             "pressure_in": 29.84,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 90,
#             "cloud": 59,
#             "feelslike_c": 10.2,
#             "feelslike_f": 50.4,
#             "windchill_c": 10.2,
#             "windchill_f": 50.4,
#             "heatindex_c": 10.5,
#             "heatindex_f": 50.9,
#             "dewpoint_c": 9.0,
#             "dewpoint_f": 48.2,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 6.9,
#             "gust_kph": 11.2,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694613600,
#             "time": "2023-09-13 08:00",
#             "temp_c": 11.3,
#             "temp_f": 52.3,
#             "is_day": 1,
#             "condition": {
#               "text": "Cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/119.png",
#               "code": 1006
#             },
#             "wind_mph": 4.5,
#             "wind_kph": 7.2,
#             "wind_degree": 282,
#             "wind_dir": "WNW",
#             "pressure_mb": 1011.0,
#             "pressure_in": 29.86,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 89,
#             "cloud": 74,
#             "feelslike_c": 10.7,
#             "feelslike_f": 51.3,
#             "windchill_c": 10.7,
#             "windchill_f": 51.3,
#             "heatindex_c": 11.3,
#             "heatindex_f": 52.3,
#             "dewpoint_c": 9.6,
#             "dewpoint_f": 49.3,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 8.1,
#             "gust_kph": 13.0,
#             "uv": 3.0
#           },
#           {
#             "time_epoch": 1694617200,
#             "time": "2023-09-13 09:00",
#             "temp_c": 14.2,
#             "temp_f": 57.6,
#             "is_day": 1,
#             "condition": {
#               "text": "Sunny",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#               "code": 1000
#             },
#             "wind_mph": 5.4,
#             "wind_kph": 8.6,
#             "wind_degree": 319,
#             "wind_dir": "NW",
#             "pressure_mb": 1014.0,
#             "pressure_in": 29.95,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 56,
#             "cloud": 2,
#             "feelslike_c": 12.9,
#             "feelslike_f": 55.2,
#             "windchill_c": 12.9,
#             "windchill_f": 55.2,
#             "heatindex_c": 14.2,
#             "heatindex_f": 57.6,
#             "dewpoint_c": 5.7,
#             "dewpoint_f": 42.3,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 7.6,
#             "gust_kph": 12.2,
#             "uv": 4.0
#           },
#           {
#             "time_epoch": 1694620800,
#             "time": "2023-09-13 10:00",
#             "temp_c": 14.6,
#             "temp_f": 58.3,
#             "is_day": 1,
#             "condition": {
#               "text": "Partly cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/116.png",
#               "code": 1003
#             },
#             "wind_mph": 4.7,
#             "wind_kph": 7.6,
#             "wind_degree": 348,
#             "wind_dir": "NNW",
#             "pressure_mb": 1012.0,
#             "pressure_in": 29.88,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 75,
#             "cloud": 46,
#             "feelslike_c": 14.4,
#             "feelslike_f": 57.9,
#             "windchill_c": 14.4,
#             "windchill_f": 57.9,
#             "heatindex_c": 14.6,
#             "heatindex_f": 58.3,
#             "dewpoint_c": 10.2,
#             "dewpoint_f": 50.4,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 5.6,
#             "gust_kph": 9.0,
#             "uv": 4.0
#           },
#           {
#             "time_epoch": 1694624400,
#             "time": "2023-09-13 11:00",
#             "temp_c": 16.3,
#             "temp_f": 61.3,
#             "is_day": 1,
#             "condition": {
#               "text": "Partly cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/116.png",
#               "code": 1003
#             },
#             "wind_mph": 4.3,
#             "wind_kph": 6.8,
#             "wind_degree": 23,
#             "wind_dir": "NNE",
#             "pressure_mb": 1011.0,
#             "pressure_in": 29.87,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 65,
#             "cloud": 30,
#             "feelslike_c": 16.3,
#             "feelslike_f": 61.3,
#             "windchill_c": 16.3,
#             "windchill_f": 61.3,
#             "heatindex_c": 16.3,
#             "heatindex_f": 61.3,
#             "dewpoint_c": 9.6,
#             "dewpoint_f": 49.3,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 6.0,
#             "gust_kph": 9.7,
#             "uv": 5.0
#           },
#           {
#             "time_epoch": 1694628000,
#             "time": "2023-09-13 12:00",
#             "temp_c": 18.9,
#             "temp_f": 66.0,
#             "is_day": 1,
#             "condition": {
#               "text": "Sunny",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#               "code": 1000
#             },
#             "wind_mph": 5.1,
#             "wind_kph": 8.3,
#             "wind_degree": 39,
#             "wind_dir": "NE",
#             "pressure_mb": 1014.0,
#             "pressure_in": 29.94,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 42,
#             "cloud": 11,
#             "feelslike_c": 18.9,
#             "feelslike_f": 66.0,
#             "windchill_c": 18.9,
#             "windchill_f": 66.0,
#             "heatindex_c": 18.9,
#             "heatindex_f": 66.0,
#             "dewpoint_c": 5.6,
#             "dewpoint_f": 42.1,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 5.8,
#             "gust_kph": 9.4,
#             "uv": 5.0
#           },
#           {
#             "time_epoch": 1694631600,
#             "time": "2023-09-13 13:00",
#             "temp_c": 18.7,
#             "temp_f": 65.7,
#             "is_day": 1,
#             "condition": {
#               "text": "Sunny",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#               "code": 1000
#             },
#             "wind_mph": 4.3,
#             "wind_kph": 6.8,
#             "wind_degree": 55,
#             "wind_dir": "NE",
#             "pressure_mb": 1011.0,
#             "pressure_in": 29.86,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 52,
#             "cloud": 21,
#             "feelslike_c": 18.7,
#             "feelslike_f": 65.7,
#             "windchill_c": 18.7,
#             "windchill_f": 65.7,
#             "heatindex_c": 18.7,
#             "heatindex_f": 65.7,
#             "dewpoint_c": 8.6,
#             "dewpoint_f": 47.5,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 4.9,
#             "gust_kph": 7.9,
#             "uv": 5.0
#           },
#           {
#             "time_epoch": 1694635200,
#             "time": "2023-09-13 14:00",
#             "temp_c": 20.1,
#             "temp_f": 68.2,
#             "is_day": 1,
#             "condition": {
#               "text": "Sunny",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#               "code": 1000
#             },
#             "wind_mph": 3.1,
#             "wind_kph": 5.0,
#             "wind_degree": 83,
#             "wind_dir": "E",
#             "pressure_mb": 1011.0,
#             "pressure_in": 29.85,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 45,
#             "cloud": 18,
#             "feelslike_c": 20.1,
#             "feelslike_f": 68.2,
#             "windchill_c": 20.1,
#             "windchill_f": 68.2,
#             "heatindex_c": 20.1,
#             "heatindex_f": 68.2,
#             "dewpoint_c": 7.9,
#             "dewpoint_f": 46.2,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 3.8,
#             "gust_kph": 6.1,
#             "uv": 6.0
#           },
#           {
#             "time_epoch": 1694638800,
#             "time": "2023-09-13 15:00",
#             "temp_c": 22.5,
#             "temp_f": 72.5,
#             "is_day": 1,
#             "condition": {
#               "text": "Sunny",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#               "code": 1000
#             },
#             "wind_mph": 2.9,
#             "wind_kph": 4.7,
#             "wind_degree": 110,
#             "wind_dir": "ESE",
#             "pressure_mb": 1013.0,
#             "pressure_in": 29.9,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 34,
#             "cloud": 0,
#             "feelslike_c": 23.8,
#             "feelslike_f": 74.8,
#             "windchill_c": 22.5,
#             "windchill_f": 72.5,
#             "heatindex_c": 23.8,
#             "heatindex_f": 74.8,
#             "dewpoint_c": 5.9,
#             "dewpoint_f": 42.6,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 9.0,
#             "vis_miles": 5.0,
#             "gust_mph": 3.6,
#             "gust_kph": 5.8,
#             "uv": 6.0
#           },
#           {
#             "time_epoch": 1694642400,
#             "time": "2023-09-13 16:00",
#             "temp_c": 20.9,
#             "temp_f": 69.6,
#             "is_day": 1,
#             "condition": {
#               "text": "Thundery outbreaks possible",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/200.png",
#               "code": 1087
#             },
#             "wind_mph": 3.4,
#             "wind_kph": 5.4,
#             "wind_degree": 124,
#             "wind_dir": "SE",
#             "pressure_mb": 1010.0,
#             "pressure_in": 29.83,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 40,
#             "cloud": 44,
#             "feelslike_c": 20.9,
#             "feelslike_f": 69.6,
#             "windchill_c": 20.9,
#             "windchill_f": 69.6,
#             "heatindex_c": 20.9,
#             "heatindex_f": 69.6,
#             "dewpoint_c": 6.8,
#             "dewpoint_f": 44.2,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 9.0,
#             "vis_miles": 5.0,
#             "gust_mph": 4.3,
#             "gust_kph": 6.8,
#             "uv": 5.0
#           },
#           {
#             "time_epoch": 1694646000,
#             "time": "2023-09-13 17:00",
#             "temp_c": 20.7,
#             "temp_f": 69.3,
#             "is_day": 1,
#             "condition": {
#               "text": "Thundery outbreaks possible",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/200.png",
#               "code": 1087
#             },
#             "wind_mph": 3.8,
#             "wind_kph": 6.1,
#             "wind_degree": 109,
#             "wind_dir": "ESE",
#             "pressure_mb": 1010.0,
#             "pressure_in": 29.82,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 40,
#             "cloud": 70,
#             "feelslike_c": 20.7,
#             "feelslike_f": 69.3,
#             "windchill_c": 20.7,
#             "windchill_f": 69.3,
#             "heatindex_c": 20.7,
#             "heatindex_f": 69.3,
#             "dewpoint_c": 6.7,
#             "dewpoint_f": 44.1,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 9.0,
#             "vis_miles": 5.0,
#             "gust_mph": 4.7,
#             "gust_kph": 7.6,
#             "uv": 5.0
#           },
#           {
#             "time_epoch": 1694649600,
#             "time": "2023-09-13 18:00",
#             "temp_c": 21.2,
#             "temp_f": 70.2,
#             "is_day": 1,
#             "condition": {
#               "text": "Sunny",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/113.png",
#               "code": 1000
#             },
#             "wind_mph": 4.3,
#             "wind_kph": 6.8,
#             "wind_degree": 85,
#             "wind_dir": "E",
#             "pressure_mb": 1012.0,
#             "pressure_in": 29.88,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 31,
#             "cloud": 0,
#             "feelslike_c": 21.2,
#             "feelslike_f": 70.2,
#             "windchill_c": 21.2,
#             "windchill_f": 70.2,
#             "heatindex_c": 23.1,
#             "heatindex_f": 73.6,
#             "dewpoint_c": 3.3,
#             "dewpoint_f": 37.9,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 5.8,
#             "gust_kph": 9.4,
#             "uv": 6.0
#           },
#           {
#             "time_epoch": 1694653200,
#             "time": "2023-09-13 19:00",
#             "temp_c": 16.6,
#             "temp_f": 61.9,
#             "is_day": 1,
#             "condition": {
#               "text": "Partly cloudy",
#               "icon": "//cdn.weatherapi.com/weather/64x64/day/116.png",
#               "code": 1003
#             },
#             "wind_mph": 3.8,
#             "wind_kph": 6.1,
#             "wind_degree": 69,
#             "wind_dir": "ENE",
#             "pressure_mb": 1012.0,
#             "pressure_in": 29.87,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 59,
#             "cloud": 46,
#             "feelslike_c": 16.6,
#             "feelslike_f": 61.9,
#             "windchill_c": 16.6,
#             "windchill_f": 61.9,
#             "heatindex_c": 16.6,
#             "heatindex_f": 61.9,
#             "dewpoint_c": 8.7,
#             "dewpoint_f": 47.7,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 7.2,
#             "gust_kph": 11.5,
#             "uv": 5.0
#           },
#           {
#             "time_epoch": 1694656800,
#             "time": "2023-09-13 20:00",
#             "temp_c": 15.2,
#             "temp_f": 59.4,
#             "is_day": 0,
#             "condition": {
#               "text": "Clear",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/113.png",
#               "code": 1000
#             },
#             "wind_mph": 2.9,
#             "wind_kph": 4.7,
#             "wind_degree": 78,
#             "wind_dir": "ENE",
#             "pressure_mb": 1012.0,
#             "pressure_in": 29.89,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 63,
#             "cloud": 24,
#             "feelslike_c": 15.2,
#             "feelslike_f": 59.4,
#             "windchill_c": 15.2,
#             "windchill_f": 59.4,
#             "heatindex_c": 15.2,
#             "heatindex_f": 59.4,
#             "dewpoint_c": 8.3,
#             "dewpoint_f": 46.9,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 6.0,
#             "gust_kph": 9.7,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694660400,
#             "time": "2023-09-13 21:00",
#             "temp_c": 16.5,
#             "temp_f": 61.7,
#             "is_day": 0,
#             "condition": {
#               "text": "Clear",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/113.png",
#               "code": 1000
#             },
#             "wind_mph": 2.5,
#             "wind_kph": 4.0,
#             "wind_degree": 343,
#             "wind_dir": "NNW",
#             "pressure_mb": 1015.0,
#             "pressure_in": 29.96,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 44,
#             "cloud": 24,
#             "feelslike_c": 16.5,
#             "feelslike_f": 61.7,
#             "windchill_c": 16.5,
#             "windchill_f": 61.7,
#             "heatindex_c": 16.5,
#             "heatindex_f": 61.7,
#             "dewpoint_c": 4.1,
#             "dewpoint_f": 39.4,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 5.1,
#             "gust_kph": 8.3,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694664000,
#             "time": "2023-09-13 22:00",
#             "temp_c": 12.0,
#             "temp_f": 53.6,
#             "is_day": 0,
#             "condition": {
#               "text": "Clear",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/113.png",
#               "code": 1000
#             },
#             "wind_mph": 5.4,
#             "wind_kph": 8.6,
#             "wind_degree": 339,
#             "wind_dir": "NNW",
#             "pressure_mb": 1015.0,
#             "pressure_in": 29.97,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 82,
#             "cloud": 22,
#             "feelslike_c": 11.2,
#             "feelslike_f": 52.2,
#             "windchill_c": 11.2,
#             "windchill_f": 52.2,
#             "heatindex_c": 12.0,
#             "heatindex_f": 53.6,
#             "dewpoint_c": 9.0,
#             "dewpoint_f": 48.2,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 11.2,
#             "gust_kph": 18.0,
#             "uv": 1.0
#           },
#           {
#             "time_epoch": 1694667600,
#             "time": "2023-09-13 23:00",
#             "temp_c": 11.4,
#             "temp_f": 52.5,
#             "is_day": 0,
#             "condition": {
#               "text": "Clear",
#               "icon": "//cdn.weatherapi.com/weather/64x64/night/113.png",
#               "code": 1000
#             },
#             "wind_mph": 4.7,
#             "wind_kph": 7.6,
#             "wind_degree": 346,
#             "wind_dir": "NNW",
#             "pressure_mb": 1016.0,
#             "pressure_in": 30.0,
#             "precip_mm": 0.0,
#             "precip_in": 0.0,
#             "humidity": 85,
#             "cloud": 19,
#             "feelslike_c": 10.8,
#             "feelslike_f": 51.4,
#             "windchill_c": 10.8,
#             "windchill_f": 51.4,
#             "heatindex_c": 11.4,
#             "heatindex_f": 52.5,
#             "dewpoint_c": 9.1,
#             "dewpoint_f": 48.4,
#             "will_it_rain": 0,
#             "chance_of_rain": 0,
#             "will_it_snow": 0,
#             "chance_of_snow": 0,
#             "vis_km": 10.0,
#             "vis_miles": 6.0,
#             "gust_mph": 9.8,
#             "gust_kph": 15.8,
#             "uv": 1.0
#           }
#         ]
#       }
#     ]
#   }
# }

# %%
astro = sample_response.json()['forecast']['forecastday'][0]['astro']
print(astro)
# Out:
# {'sunrise': '07:08 AM', 'sunset': '07:55 PM', 'moonrise': '05:21 AM', 'moonset': '07:53 PM', 'moon_phase': 'Waning Crescent', 'moon_illumination': '4'}

# %%
# Great! We will create the loop to collect the data
data_list = [['sunrise', 'sunset', 'moonrise', 'moonset', 'moon_illumination']]
start_date = dt.date(year=2022, month=1, day=1)
date_increment = dt.timedelta(days=1)
end_date = dt.date(year=2022, month=1, day=5)

# %%
def getDesiredList(response) :
    temp_astro = response.json()['forecast']['forecastday'][0]['astro']
    temp_list = [temp_astro['sunrise'], temp_astro['sunset'], temp_astro['moonrise'], temp_astro['moonset'], temp_astro['moon_illumination']]
    
    return [datetime.strptime(time, '%I:%M %p').strftime('%H:%M') for time in temp_list[:3]]

# %%
current_date = start_date
params = { 'key':api_key , 'q':'Calgary', 'dt':current_date.isoformat() }
#while current_date < end_date :
current_response = requests.get('http://api.weatherapi.com/v1/history.json', params=params)
#    data_list.append(getDesiredList(current_response))
#    print(current_date)
#    current_date += date_increment

# %%
print(current_response.status_code)
print(current_date.isoformat())
# Out:
# 400
# 2022-01-01
